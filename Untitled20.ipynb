# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('merc.csv')

print(df)
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 6       GLE Class  2018   30948    Automatic    16000   Diesel  145  47.9
# 7         S Class  2012   10948    Automatic   107000   Petrol  265  36.7
# 8         G Class  2019  139948    Automatic    12000   Petrol  145  21.4
# 9       GLA Class  2017   19750    Automatic    15258   Diesel   30  64.2
# 10        A Class  2020   32980    Automatic      606   Petrol  145  35.8
# 11        A Class  2020   26980    Automatic     1000   Diesel  145  62.8
# ...

# %%
print(df.head(10))
# Out:
#         model  year   price transmission  mileage fuelType  tax   mpg  \
# 0         SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 1     S Class  2017   34948    Automatic    27000   Hybrid   20  61.4
# 2    SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3     G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4     G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5    SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 6   GLE Class  2018   30948    Automatic    16000   Diesel  145  47.9
# 7     S Class  2012   10948    Automatic   107000   Petrol  265  36.7
# 8     G Class  2019  139948    Automatic    12000   Petrol  145  21.4
# 9   GLA Class  2017   19750    Automatic    15258   Diesel   30  64.2
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0
# 5         6.2
# 6         2.1
# 7         3.5
# 8         4.0
# 9         2.1

# %%
print(df.tail())
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df.plot()

plt.show()

# %%
df.plot(kind = 'scatter', x = 'year', y = 'price')

plt.show()

# %%
df.plot(kind = 'hist', x = 'year', y = 'price')

plt.show()

# %%
df.plot(kind = 'hist', x = 'year', y = 'price')

plt.show()

# %%
df.plot(kind = 'bar', x = 'year', y = 'price')

plt.show()

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
# ...

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.plot(kind = 'line', x = 'year', y = 'price')

plt.show()

# %%
from pandas.plotting import scatter_matrix
attributes = ["year", "tax", "mpg", "price"]
scatter_matrix(df[attributes], figsize = (12,8))
# Out:
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
# ...

# %%
df.plot(kind = 'bar', x = 'mpg', y = 'price' ,color = "hotpink")

plt.show()

# %%
df.plot(kind = 'scatter', x = 'mpg', y = 'price' ,color = "hotpink")
plt.show()

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df.plot(kind = 'scatter', x = 'engineSize', y = 'mileage' ,color = "red")
plt.show()

# %%
df.plot(kind = 'hist', x = 'engineSize', y = 'mileage' ,color = "red")
plt.show()

# %%
df.plot(kind = 'bar', x = 'engineSize', y = 'mileage' ,color = "red")
plt.show()

# %%
sns.pairplot(df)

# %%
df.shape
# Out:
# (13119, 9)

# %%
res=sns.barplot(df['engineSize'],df['mileage'])
plt.show()
# Out:
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
res=sns.barplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.scatterplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.histplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.lineplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.barplot(x='engineSize',y='year',data=df, color='green')
plt.show()

# %%
res=sns.barplot(df['engineSize'],df['mileage'],palette="Set2")
plt.show()
# Out:
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
res=sns.barplot(df['engineSize'],df['mileage'],palette="rocket")
plt.show()
# Out:
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.heatmap(df.corr(),cbar=True,linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
res=sns.scatterplot(x='engineSize',y='year',data=df,hue ='engineSize')
plt.show()

# %%
sns.pairplot(df,hue = 'engineSize',palette='Set1')

# %%
res=sns.lmplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.boxplot(x='engineSize',y='year',data=df)
plt.show()

# %%
res=sns.lmplot(x='year',y='price',data=df)
plt.show()

# %%
res=sns.lmplot(y='year',x='engineSize',data=df)
plt.show()

# %%
#logistic regression# gradient decent#lasso regression#Ridge regressions# support vector regression#neural network regression

# %%
df.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
def plot_corr(df, size=11):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df.shape
# Out:
# (13119, 9)

# %%
sns.pairplot(df,diag_kind='kde')

# %%
from sklearn.model_selection import train_test_split

X = df.drop('engineSize',axis=1)     # Predictor feature columns (8 X m)
Y = df['engineSize']   # Predicted class (1=True, 0=False) (1 X m)

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
# 1 is just any random seed number

x_train.head()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg
# 8769    GLE Class  2018  31999    Semi-Auto    11510   Diesel  145  47.9
# 10218   GLC Class  2017  25998    Automatic    35224   Diesel  125  56.5
# 7379      E Class  2019  54000    Semi-Auto     5648   Petrol  145  31.7
# 4815      B Class  2019  21980    Automatic    13765   Petrol  145  45.6
# 3645      C Class  2018  23500    Automatic     4368   Petrol  145  44.1

# %%
print(list(df.keys()))
# Out:
# ['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg', 'engineSize']

# %%
print(df['fuelType'])
# Out:
# 0        Petrol
# 1        Hybrid
# 2        Petrol
# 3        Petrol
# 4        Petrol
# 5        Petrol
# 6        Diesel
# 7        Petrol
# 8        Petrol
# 9        Diesel
# 10       Petrol
# 11       Diesel
# 12       Diesel
# 13       Petrol
# 14       Diesel
# 15       Diesel
# 16       Diesel
# 17       Petrol
# 18       Diesel
# 19       Diesel
# 20       Diesel
# 21       Diesel
# 22       Diesel
# 23       Diesel
# 24       Diesel
# 25       Diesel
# 26       Diesel
# 27       Diesel
# 28       Petrol
# 29       Diesel
#           ...
# 13089    Diesel
# 13090    Diesel
# 13091    Diesel
# 13092    Diesel
# 13093    Petrol
# 13094    Diesel
# 13095    Diesel
# 13096    Diesel
# 13097    Diesel
# 13098    Petrol
# 13099    Petrol
# 13100    Diesel
# 13101    Diesel
# 13102    Petrol
# 13103    Diesel
# 13104    Diesel
# 13105    Diesel
# 13106    Petrol
# 13107    Diesel
# 13108    Diesel
# 13109    Diesel
# 13110    Diesel
# 13111    Petrol
# 13112    Diesel
# ...

# %%
x_train.head()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg
# 8769    GLE Class  2018  31999    Semi-Auto    11510   Diesel  145  47.9
# 10218   GLC Class  2017  25998    Automatic    35224   Diesel  125  56.5
# 7379      E Class  2019  54000    Semi-Auto     5648   Petrol  145  31.7
# 4815      B Class  2019  21980    Automatic    13765   Petrol  145  45.6
# 3645      C Class  2018  23500    Automatic     4368   Petrol  145  44.1

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.drop(['fuelType'], axis = 1)
# Out:
#             model  year   price transmission  mileage  tax   mpg  engineSize
# 0             SLK  2005    5200    Automatic    63000  325  32.1         1.8
# 1         S Class  2017   34948    Automatic    27000   20  61.4         2.1
# 2        SL CLASS  2016   49948    Automatic     6200  555  28.0         5.5
# 3         G Class  2016   61948    Automatic    16000  325  30.4         4.0
# 4         G Class  2016   73948    Automatic     4000  325  30.1         4.0
# 5        SL CLASS  2011  149948    Automatic     3000  570  21.4         6.2
# 6       GLE Class  2018   30948    Automatic    16000  145  47.9         2.1
# 7         S Class  2012   10948    Automatic   107000  265  36.7         3.5
# 8         G Class  2019  139948    Automatic    12000  145  21.4         4.0
# 9       GLA Class  2017   19750    Automatic    15258   30  64.2         2.1
# 10        A Class  2020   32980    Automatic      606  145  35.8         2.0
# ...

# %%
df.head()
# Out:
#    year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000   Petrol  325  32.1         1.8
# 1  2017  34948    Automatic    27000   Hybrid   20  61.4         2.1
# 2  2016  49948    Automatic     6200   Petrol  555  28.0         5.5
# 3  2016  61948    Automatic    16000   Petrol  325  30.4         4.0
# 4  2016  73948    Automatic     4000   Petrol  325  30.1         4.0

# %%
df = df.drop('fuelType', axis=1)

# %%
df.head()
# Out:
#        model  year  price transmission  mileage  tax   mpg  engineSize
# 0        SLK  2005   5200    Automatic    63000  325  32.1         1.8
# 1    S Class  2017  34948    Automatic    27000   20  61.4         2.1
# 2   SL CLASS  2016  49948    Automatic     6200  555  28.0         5.5
# 3    G Class  2016  61948    Automatic    16000  325  30.4         4.0
# 4    G Class  2016  73948    Automatic     4000  325  30.1         4.0

# %%
df = df.drop('transmission', axis=1)

# %%
df.head()
# Out:
#        model  year  price  mileage  tax   mpg  engineSize
# 0        SLK  2005   5200    63000  325  32.1         1.8
# 1    S Class  2017  34948    27000   20  61.4         2.1
# 2   SL CLASS  2016  49948     6200  555  28.0         5.5
# 3    G Class  2016  61948    16000  325  30.4         4.0
# 4    G Class  2016  73948     4000  325  30.1         4.0

# %%
fig = plt.figure(figsize = (12, 8))
plt.scatter(df['mileage'],df['tax'])
plt.xlabel('mileage')
plt.ylabel('tax')
plt.show()

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
df = df.drop('model', axis=1)

# %%
df.head()
# Out:
#    year  price  mileage  tax   mpg  engineSize
# 0  2005   5200    63000  325  32.1         1.8
# 1  2017  34948    27000   20  61.4         2.1
# 2  2016  49948     6200  555  28.0         5.5
# 3  2016  61948    16000  325  30.4         4.0
# 4  2016  73948     4000  325  30.1         4.0

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
x=np.array(df['price'],df['mileage']).reshape(-1,1)

# %%
x.shape
print(x)
# Out:
# [[ 5200]
#  [34948]
#  [49948]
#  ...
#  [30999]
#  [37990]
#  [54999]]

# %%
y=np.array(df['year'],df['tax'])

# %%
print(y
     )
# Out:
# [2005 2017 2016 ... 2019 2019 2019]

# %%
y.shape
# Out:
# (13119,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (10495, 1)

# %%
 y_train.shape
# Out:
# (10495,)

# %%
x_test.shape
# Out:
# (2624, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
classifier= KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = classifier.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test,pred ) * 100)
# Out:
# Accuracy: 40.8155487804878

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
DecisionTree = DecisionTreeClassifier(random_state=0)

# %%
DecisionTree.fit(x_train,x_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
pred = DecisionTree.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(x_test,pred ) * 100 )
# Out:
# Accuracy: 77.0579268292683

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# c:\users\abhaysingh\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.361, total=  20.3s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.2s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.363, total=  22.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   42.2s remaining:    0.0s
# ...

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=1, gamma=0.0001)

# %%
SVM =SVC(C=1, gamma=0.0001)
SVM.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=0.0001)

# %%
pred = SVM.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, pred) * 100)
# Out:
# Accuracy: 43.368902439024396

# %%
 #random forest#naive byes#confusion#matrix#logistic regression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn import ensemble
rf_clf = ensemble.RandomForestClassifier(n_estimators=100)
rf_clf.fit(x_train, y_train)
rf_clf.score(x_test, y_test)
# Out:
# 0.4104420731707317

# %%
#naive byes
